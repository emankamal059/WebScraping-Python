# %%
from bs4 import BeautifulSoup
import requests

# %%
amazon_URL='https://www.amazon.com/Bio-Oil-4-2oz-Multiuse-Skincare-Oil/dp/B004AI97MA/ref=sr_1_1?keywords=Bio-Oil+Skincare+Specialist+For+Scars+Stretch+Marks+Uneven+Skin+Tone%2C+New+125ml&sr=8-1'
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

page = requests.get(amazon_URL, headers=headers) 
soup = BeautifulSoup(page.content,'lxml') 
print(soup.prettify())

Soup3=BeautifulSoup(page.content,"html.parser")

Soup4=BeautifulSoup(Soup3.prettify(),"html.parser")

amazon_Title=Soup4.find(id='productTitle').get_text()

amazon_Price=Soup4.find(class_='a-offscreen').get_text()


print('\033[1mProduct Title On Amazon:\033[0m',amazon_Title)
print('\033[1mPrice On Amazon:\033[0m',amazon_Price)
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-us">
#  <!-- sp:feature:head-start -->
#  <head>
#   <script>
#    var aPageStart = (new Date()).getTime();
#   </script>
#   <meta charset="utf-8"/>
#   <!-- sp:end-feature:head-start -->
#   <!-- sp:feature:csm:head-open-part1 -->
#   <script type="text/javascript">
#    var ue_t0=ue_t0||+new Date();
#   </script>
#   <!-- sp:end-feature:csm:head-open-part1 -->
#   <!-- sp:feature:cs-optimization -->
#   <meta content="on" http-equiv="x-dns-prefetch-control"/>
#   <link href="https://images-na.ssl-images-amazon.com" rel="dns-prefetch"/>
#   <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
#   <link href="https://completion.amazon.com" rel="dns-prefetch"/>
#   <!-- sp:end-feature:cs-optimization -->
#   <!-- sp:feature:csm:head-open-part2 -->
#   <script type="text/javascript">
#    window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
# ...

# %%
ebay_URL='https://www.ebay.com/itm/403029539600?hash=item5dd66ebb10:g:nCcAAOSwWO5hA1Cs&amdata=enc%3AAQAHAAABMEa9%2FCBNOSrRqqUF460c1NqlRivDJ8P1%2BtJ0U84IEduvfvjtmmHGoNegSdu4pwfdLOKK7enWrsKuina2APmoogjyG7qEXiLgAbp02o%2BTZ4kcoYU%2FMCxdX2kZwvcntgTarEcNJ77EnBx2MgH2CmSEwyDbYshylCFCbXajlOBuO7n3u%2FHwmDNH24UN6VkK526p%2BM4HsYswPXkBWWBLoaYTxS6qQ3ymXNAEgsDSvPCRmugr%2FEOZvVkje%2BGe8BUzQ9JcnnzmdICSOhKFy6uHvtBY2Vi%2B1VF5n7qiVnO4l9sH0F%2Bke%2Bx2YmWi43uRVkTLalcbK%2BYzcraIXwYyzn0zLGDUaljkBBK%2FEYLZvbywqDTFjsCBfKf0gdqy%2BI1gVafdCaDpzBl7FJoB8LrCw1SO5vpcSJc%3D%7Ctkp%3ABFBMotiW-ONh'
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

page = requests.get(ebay_URL, headers=headers) 
soup = BeautifulSoup(page.content,'lxml') 
print(soup.prettify())

Soup3=BeautifulSoup(page.content,"html.parser")

Soup4=BeautifulSoup(Soup3.prettify(),"html.parser")

ebay_Title=Soup4.find(class_='x-item-title__mainTitle').get_text()

ebay_Price=Soup4.find(class_='x-price-approx__price').get_text()


print('\033[1mProduct Title On ebay:\033[0m',ebay_Title)
print('\033[1mPrice On ebay:\033[0m',ebay_Price)
# Out:
# <!DOCTYPE html>
# <html lang="en" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/">
#  <head>
#   <link href="//i.ebayimg.com" rel="dns-prefetch"/>
#   <link href="//thumbs.ebaystatic.com" rel="dns-prefetch"/>
#   <link href="//vi.vipr.ebaydesc.com" rel="dns-prefetch"/>
#   <link href="//p.ebaystatic.com" rel="dns-prefetch"/>
#   <link href="//q.ebaystatic.com" rel="dns-prefetch"/>
#   <link href="//pics.ebaystatic.com" rel="dns-prefetch"/>
#   <link href="//ir.ebaystatic.com" rel="dns-prefetch"/>
#   <link href="//srx.main.ebayrtm.com" rel="dns-prefetch"/>
#   <link href="//rover.ebay.com" rel="dns-prefetch"/>
#   <link href="//reco.ebay.com" rel="dns-prefetch"/>
#   <!--  fix for IE freezing.  -->
#   <style type="text/css">
#    body #Body .btn, body #Body c-std {
# filter:none;
# -ms-filter: "progid:DXImageTransform.Microsoft.gradient(startColorstr='#0079bc',endColorstr='#00509d')";
# }
#   </style>
#   <meta name="viewport"/>
# ...

# %%
#cleaning the code

print(' \033[1mProduct Title On Amazon:\033[0m', amazon_Title.strip())
print('\033[1mPrice On Amazon:\033[0m ', amazon_Price.strip())

print('\033[1mProduct Title On eBay:\033[0m ', ebay_Title.strip())
print(' \033[1mPrice On eBay:\033[0m', ebay_Price.strip())
# Out:
#  Product Title On Amazon: Bio-Oil Skincare Body Oil, Serum for Scars and Stretchmarks, Face and Body Moisturizer Dry Skin, Non-Greasy, Dermatologist Recommended, Non-Comedogenic, For All Skin Types, with Vitamin A, E, 4.2 oz
# Price On Amazon:  $16.97
# Product Title On eBay:  Bio-Oil Skincare Specialist  For Scars Stretch Marks Uneven Skin Tone, New 125ml
#  Price On eBay: US $18.16

# %%
#Storing Data 

import pickle
def storeData():
   # initializing data to be stored in db
    amazon = {'key' : 'amazon', 'amazon_Title' : 'Bio-Oil Skincare Body Oil, Serum for Scars and Stretchmarks, Face and Body Moisturizer Dry Skin, Non-Greasy, Dermatologist Recommended, Non-Comedogenic, For All Skin Types, with Vitamin A, E, 4.2 oz', 'amazon_Price' : amazon_Price}
    ebay = {'key' : 'ebay', 'ebay_Title' : 'Bio-Oil Skincare Specialist  For Scars Stretch Marks Uneven Skin Tone, New 125ml', 'ebay_Price' : ebay_Price}

   # database
    db = {}
    db['amazon'] = amazon
    db['ebay'] = ebay

    
   # Its important to use binary mode
    dbfile = open('price_data', 'ab')
    
   # source, destination
    pickle.dump(db, dbfile)                    
    dbfile.close()

# %%
#Loading Stored Data
def read_data():
    dbfile = open('price_data', 'rb')    
    sb_store = pickle.load(dbfile)
    for items in db_store:
        print(items, ' :: ', db[items])
    dbfile.close()

# %%
#Price Comparision
#Removing currency symbols and converting prices from string to float for comparison.

amazon_Price = "16.97"
ebay_Price = "18.16"

amazon_Price_float = float(amazon_Price)
ebay_Price_float = float(ebay_Price)

print(amazon_Price_float)
print(ebay_Price_float)
# Out:
# 16.97
# 18.16

# %%
min_price = min (amazon_Price,ebay_Price)

# %%
if min_price == amazon_Price:
    Company = "Amazon"
    amazon_URL = "https://www.amazon.com/Bio-Oil-4-2oz-Multiuse-Skincare-Oil/dp/B004AI97MA/ref=sr_1_1?keywords=Bio-Oil+Skincare+Specialist+For+Scars+Stretch+Marks+Uneven+Skin+Tone%2C+New+125ml&sr=8-1"
    elif min_price == ebay_Price:
    Company = "eBay"
    ebay_URL = "https://www.ebay.com/itm/403029539600?hash=item5dd66ebb10:g:nCcAAOSwWO5hA1Cs&amdata=enc%3AAQAHAAABMEa9%2FCBNOSrRqqUF460c1NqlRivDJ8P1%2BtJ0U84IEduvfvjtmmHGoNegSdu4pwfdLOKK7enWrsKuina2APmoogjyG7qEXiLgAbp02o%2BTZ4kcoYU%2FMCxdX2kZwvcntgTarEcNJ77EnBx2MgH2CmSEwyDbYshylCFCbXajlOBuO7n3u%2FHwmDNH24UN6VkK526p%2BM4HsYswPXkBWWBLoaYTxS6qQ3ymXNAEgsDSvPCRmugr%2FEOZvVkje%2BGe8BUzQ9JcnnzmdICSOhKFy6uHvtBY2Vi%2B1VF5n7qiVnO4l9sH0F%2Bke%2Bx2YmWi43uRVkTLalcbK%2BYzcraIXwYyzn0zLGDUaljkBBK%2FEYLZvbywqDTFjsCBfKf0gdqy%2BI1gVafdCaDpzBl7FJoB8LrCw1SO5vpcSJc%3D%7Ctkp%3ABFBMotiW-ONh"
    else:
    print("Invalid")

# %%
import numpy as np
import matplotlib.pyplot as plt

# creating the dataset
data = {'amazon_Price':16.97, 'ebay_Price':18.16}
pricing = list(data.keys())
values = list(data.values())

fig = plt.figure(figsize = (10, 5))

# creating the bar plot
plt.bar(pricing, values, color ='navy',
        width = 0.4)

for i in range(len(pricing)):
    plt.text(i, values[i]+5, str(values[i]) + ' USD', ha='center', fontsize=9)

#Comparison between Amazon and ebay Price for Bio Oil
plt.xlabel("Pricing")
plt.ylabel("Price in USD")
plt.title("Comparison between Amazon and ebay Price")
plt.show()

# %%
# If uou want to try sending yourself an email (just for fun) when a price hits below a certain level you can try it
# out with this script

def send_mail():
    server = smtplib.SMTP_SSL('smtp.gmail.com',465)
    server.ehlo()
    #server.starttls()
    server.ehlo()
    server.login('emankamal059@gmail.com','xxxxxxxxxxxxxxx')
    
    subject = "Bio Oil you want is below $16.97 Now is your chance to buy!"
    body = "Emaan, This is the moment we have been waiting for. Now is your chance to grab this amazing offer. Don't mess it up! Link here:https://www.ebay.com/itm/403029539600?hash=item5dd66ebb10:g:nCcAAOSwWO5hA1Cs&amdata=enc%3AAQAHAAABMEa9%2FCBNOSrRqqUF460c1NqlRivDJ8P1%2BtJ0U84IEduvfvjtmmHGoNegSdu4pwfdLOKK7enWrsKuina2APmoogjyG7qEXiLgAbp02o%2BTZ4kcoYU%2FMCxdX2kZwvcntgTarEcNJ77EnBx2MgH2CmSEwyDbYshylCFCbXajlOBuO7n3u%2FHwmDNH24UN6VkK526p%2BM4HsYswPXkBWWBLoaYTxS6qQ3ymXNAEgsDSvPCRmugr%2FEOZvVkje%2BGe8BUzQ9JcnnzmdICSOhKFy6uHvtBY2Vi%2B1VF5n7qiVnO4l9sH0F%2Bke%2Bx2YmWi43uRVkTLalcbK%2BYzcraIXwYyzn0zLGDUaljkBBK%2FEYLZvbywqDTFjsCBfKf0gdqy%2BI1gVafdCaDpzBl7FJoB8LrCw1SO5vpcSJc%3D%7Ctkp%3ABFBMotiW-ONh"
   
   
    msg = f"Subject: {subject}\n\n{body}"
    
    server.sendmail(
        'emankamal059@gmail.com',
        msg
     
    )
